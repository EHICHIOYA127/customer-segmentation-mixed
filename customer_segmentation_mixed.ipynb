# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# The problems to analyse are:

# %%
customer_age = []
customer_gender = []
customer_annual_income = []
customer_spending_score = []
customer_monthly_visits = []
customer_preferred_product = []

# %%
cust_seg = pd.read_csv('customer_segmentation_mixed.csv')

# %%
# This command shows us how many users visited the site from different sources in different months.
df.groupby(['month', 'utm_source']).id.count()\
    .reset_index()\
    .pivot(columns='month', index='utm_source', values='id')

# %%
orders = pd.read_csv('orders.csv')
pricey_shoes = orders.groupby('shoe_type').price.max()
print(pricey_shoes)
print(type(pricey_shoes))

# %%
cust_seg.head(20)
# Out:
#     Age  Annual_Income  Spending_Score  Monthly_Visits  Gender  \
# 0    56          26102              85               6  Female
# 1    46          70336              75              18    Male
# 2    32         105314              36              10    Male
# 3    60          46641              99               5  Female
# 4    25          54584              19              10    Male
# 5    38          52745              20              12    Male
# 6    56          43093              57               2    Male
# 7    36          86105              18              13    Male
# 8    40          71885              47               8    Male
# 9    28          56631              49               2  Female
# 10   28          92991              14               1    Male
# 11   41          24014              15               5    Male
# 12   53          31093              31               9    Male
# 13   57          38070               1              17    Male
# 14   41          55777              54               9  Female
# 15   20          76958               3              11  Female
# 16   39         102074              16              15  Female
# 17   19          30729              87               6  Female
# 18   41         119713              57               3    Male
# 19   61          65017              75              17  Female
#
#    Preferred_Product
# 0           Clothing
# 1               Home
# 2          Groceries
# 3        Electronics
# 4        Electronics
# 5        Electronics
# 6           Clothing
# 7             Sports
# 8               Home
# 9          Groceries
# 10         Groceries
# 11          Clothing
# 12       Electronics
# 13          Clothing
# 14            Sports
# 15            Sports
# 16              Home
# 17              Home
# 18            Sports
# 19            Sports

# %%
cust_seg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                350 non-null    int64
#  1   Annual_Income      350 non-null    int64
#  2   Spending_Score     350 non-null    int64
#  3   Monthly_Visits     350 non-null    int64
#  4   Gender             350 non-null    object
#  5   Preferred_Product  350 non-null    object
# dtypes: int64(4), object(2)
# memory usage: 16.5+ KB

# %% [markdown]
# The dataset contains 350 rows and 6 columns. The columns are:

# %% [markdown]
# Visualizing the data
# Finally, we can create visualizations to get a better understanding of the data. For example, we can use a histogram to visualize the distribution of a numerical column (age).

# %%
plt.hist(cust_seg['Age'], bins=10)
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Analysis of Insurance Dataset

# %%
# Calculate the average age
avg_age = cust_seg['Age'].mean()

print('The average age of the customers is: {} years.'.format(round(avg_age, 2)))
# Out:
# The average age of the customers is: 41.2 years.

# %% [markdown]
#  Analysis to determine the total number of males and females in the dataset

# %%
cust_seg.groupby('Gender')['Gender'].count()
# Out:
# Gender
# Female    159
# Male      191
# Name: Gender, dtype: int64

# %% [markdown]
# Analysis to determine the average annual income ofthe customers

# %%
# Calculate the average annual income
avg_annual_income = cust_seg['Annual_Income'].mean()

print('The Average Annual Income of the customers is:  {} dollars.'.format(round(avg_annual_income, 2)))
# Out:
# The Average Annual Income of the customers is:  71213.27 dollars.

# %% [markdown]
# The average number of times the customers visited per month

# %%
# Calculate the average monthly visits
avg_monthly_visits = cust_seg['Monthly_Visits'].mean()

print('The Average Monthly Visits of the customers is:  {} times per month.'.format(round(avg_monthly_visits, 2)))
# Out:
# The Average Monthly Visits of the customers is:  9.52 times per month.

# %% [markdown]
# Analysis the average spending score of the customers in the dataset

# %%
# Calculate the average spending score
avg_spending_score = cust_seg['Spending_Score'].mean()

print('The Average Spending Score of the customers is:  {} dollars.'.format(round(avg_spending_score, 2)))
# Out:
# The Average Spending Score of the customers is:  49.57 dollars.

# %% [markdown]
# This code investigates the top five(5) preferred product by age group

# %%
Product_counts = cust_seg.groupby('Preferred_Product').Age.count().reset_index()
print(Product_counts)
# Out:
#   Preferred_Product  Age
# 0          Clothing   72
# 1       Electronics   67
# 2         Groceries   61
# 3              Home   67
# 4            Sports   83
